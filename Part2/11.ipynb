# %%
from datetime import datetime
datetime.today()
# Out:
# datetime.datetime(2026, 4, 10, 16, 3, 40, 785688)

# %%
datetime.today().year
# Out:
# 2026

# %%
datetime.strptime("2022-01-01 00:00:01", "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2022, 1, 1, 0, 0, 1)

# %%
datetime.today().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2026-04-10 16:23:46'

# %%
from datetime import timedelta
time = datetime.today()
time + timedelta(days=100)
# Out:
# datetime.datetime(2026, 7, 19, 16, 24, 52, 375176)
