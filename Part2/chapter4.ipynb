# %%
import pandas as pd
import numpy as np

students = pd.DataFrame({"이름": ["장화", "홍련", "콩쥐", "팥쥐", "햇님", "달님"],
"국어": [70, 85, None, 100, None, 85],
"수학": [65, 100, 80, 95, None, 70]})

# %%
# students["이름"] == "장화"
# type(students["이름"] == "장화")
# students[students["이름"] == "장화"]
students[[True,False,False,False,False,False]]
# Out:
#    이름    국어    수학
# 0  장화  70.0  65.0

# %%
# students[(students["국어"] >= 80) & (students["수학"] >= 80)]
(students["국어"] >= 80) & (students["수학"] >= 80)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
students.loc[6] = ["별님", 50, 60]
students
# Out:
#    이름     국어     수학
# 0  장화   70.0   65.0
# 1  홍련   85.0  100.0
# 2  콩쥐    NaN   80.0
# 3  팥쥐  100.0   95.0
# 4  햇님    NaN    NaN
# 5  달님   85.0   70.0
# 6  별님   50.0   60.0

# %%
students.loc[(students["국어"]>=80)&(students["수학"]>=80), "합격"] = "Pass"
students
# Out:
#    이름     국어     수학    합격
# 0  장화   70.0   65.0   NaN
# 1  홍련   85.0  100.0  Pass
# 2  콩쥐    NaN   80.0   NaN
# 3  팥쥐  100.0   95.0  Pass
# 4  햇님    NaN    NaN   NaN
# 5  달님   85.0   70.0   NaN
# 6  별님   50.0   60.0   NaN

# %%
students.loc[students["합격"] != "Pass", "합격"] = "Fail"
students
# Out:
#    이름     국어     수학    합격
# 0  장화   70.0   65.0  Fail
# 1  홍련   85.0  100.0  Pass
# 2  콩쥐    NaN   80.0  Fail
# 3  팥쥐  100.0   95.0  Pass
# 4  햇님    NaN    NaN  Fail
# 5  달님   85.0   70.0  Fail
# 6  별님   50.0   60.0  Fail

# %%
condition_list= [(students["국어"] >= 90),
                 (students["국어"] >= 80) & (students["국어"] < 90),
                 (students["국어"] >= 70) & (students["국어"] < 90)]
choice_list = ["A", "B", "C"]
students["국어등급"] = np.select(condition_list, choice_list, "F")
students
# Out:
#    이름     국어     수학    합격 국어등급
# 0  장화   70.0   65.0  Fail    C
# 1  홍련   85.0  100.0  Pass    B
# 2  콩쥐    NaN   80.0  Fail    F
# 3  팥쥐  100.0   95.0  Pass    A
# 4  햇님    NaN    NaN  Fail    F
# 5  달님   85.0   70.0  Fail    B
# 6  별님   50.0   60.0  Fail    F

# %%
students.isna()
# Out:
#       이름     국어     수학     합격   국어등급
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False  False
# 3  False  False  False  False  False
# 4  False   True   True  False  False
# 5  False  False  False  False  False
# 6  False  False  False  False  False

# %%
students.isnull()
# Out:
#       이름     국어     수학     합격   국어등급
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False   True  False  False  False
# 3  False  False  False  False  False
# 4  False   True   True  False  False
# 5  False  False  False  False  False
# 6  False  False  False  False  False

# %%
students.notna()
# Out:
#      이름     국어     수학    합격  국어등급
# 0  True   True   True  True  True
# 1  True   True   True  True  True
# 2  True  False   True  True  True
# 3  True   True   True  True  True
# 4  True  False  False  True  True
# 5  True   True   True  True  True
# 6  True   True   True  True  True

# %%
students["국어"].isna()
# type(students["장화"])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# Name: 국어, dtype: bool

# %%
students.isna().sum(0)
# Out:
# 이름      0
# 국어      2
# 수학      1
# 합격      0
# 국어등급    0
# dtype: int64

# %%
st_nameindex = students.set_index("이름",drop=True)
st_nameindex.isna().sum(1)
# Out:
# 이름
# 장화    0
# 홍련    0
# 콩쥐    1
# 팥쥐    0
# 햇님    2
# 달님    0
# 별님    0
# dtype: int64

# %%
students.dropna()
# Out:
#    이름     국어     수학    합격 국어등급
# 0  장화   70.0   65.0  Fail    C
# 1  홍련   85.0  100.0  Pass    B
# 3  팥쥐  100.0   95.0  Pass    A
# 5  달님   85.0   70.0  Fail    B
# 6  별님   50.0   60.0  Fail    F

# %%
students.dropna(axis=1)
# Out:
#    이름    합격 국어등급
# 0  장화  Fail    C
# 1  홍련  Pass    B
# 2  콩쥐  Fail    F
# 3  팥쥐  Pass    A
# 4  햇님  Fail    F
# 5  달님  Fail    B
# 6  별님  Fail    F

# %%
students.dropna(thresh=4)
#햇님만 사라졌다.
# Out:
#    이름     국어     수학    합격 국어등급
# 0  장화   70.0   65.0  Fail    C
# 1  홍련   85.0  100.0  Pass    B
# 2  콩쥐    NaN   80.0  Fail    F
# 3  팥쥐  100.0   95.0  Pass    A
# 5  달님   85.0   70.0  Fail    B
# 6  별님   50.0   60.0  Fail    F
