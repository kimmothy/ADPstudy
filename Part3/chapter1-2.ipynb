# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine


wine_load = load_wine()
wine = pd.DataFrame(data=wine_load.data, columns=wine_load.feature_names)
wine['Class'] = wine_load.target
wine['Class'] = wine["Class"].map({0:'class_0', 1:'class_1',2:'class_2'})

# %%
print(type(wine_load.target))
print(type(wine_load.data))
print(type(wine_load.feature_names))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'list'>

# %%
wine_type = wine['Class'].value_counts()
wine_type
# Out:
# Class
# class_1    71
# class_0    59
# class_2    48
# Name: count, dtype: int64

# %%
plt.bar(wine_type.index, wine_type.values, width=0.8, bottom= None, align='center')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(wine_type.index, wine_type.values, height=0.8, left= 0, align='edge')
# Out:
# <BarContainer object of 3 artists>

# %%
#range는 반드시 전체 데이터를 포함하도록 잡을 것
plt.title("Wine alchgol histogram")
plt.hist('alcohol', bins=8, range=(11,15), color='red', data=wine)
# Out:
# (array([ 4., 15., 38., 29., 35., 35., 20.,  2.]),
#  array([11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. ]),
#  <BarContainer object of 8 artists>)
